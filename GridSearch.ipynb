# %% [markdown]
# <a href="https://colab.research.google.com/github/Tomaz4lves/Biblioteca_pandas/blob/main/GridSearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Carregar os dados do banco de dados
casa = pd.read_excel("house_2.xlsx")
casa.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea ExterQual  ... WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0        Gd  ...          0           61
# 1          1976         0.0        TA  ...        298            0
# 2          2002       162.0        Gd  ...          0           42
# 3          1970         0.0        TA  ...          0           35
# 4          2000       350.0        Gd  ...        192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
casa = casa.dropna()

# %%
# Verificar e lidar com valores nulos
print('Valores nulos antes da limpeza:')
print(casa.isnull().sum())
# Out:
# Valores nulos antes da limpeza:
# Id               0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageYrBlt      0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# SalePrice        0
# dtype: int64

# %%
casa.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1121.000000  1121.000000  1121.000000    1121.000000  1121.000000
# mean    726.842105    56.146298    70.665477   10122.956289     6.212310
# std     420.769012    41.772684    24.266812    8129.302641     1.380822
# min       1.000000    20.000000    21.000000    1300.000000     2.000000
# 25%     364.000000    20.000000    60.000000    7590.000000     5.000000
# 50%     725.000000    50.000000    70.000000    9416.000000     6.000000
# 75%    1091.000000    70.000000    80.000000   11361.000000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1121.000000  1121.000000   1121.000000  1121.000000  1121.000000  ...
# mean      5.561106  1972.264942   1985.683318   108.487957   438.399643  ...
# std       1.068236    30.967730     21.025974   189.500966   468.385038  ...
# ...

# %%
#Codificar os dados usando one-hot encoding
casa = pd.get_dummies(casa)
casa.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  YrSold  SalePrice  ExterQual_Ex  \
# 0          2003       196.0         706  ...    2008     208500             0
# 1          1976         0.0         978  ...    2007     181500             0
# 2          2002       162.0         486  ...    2008     223500             0
# 3          1970         0.0         216  ...    2006     140000             0
# 4          2000       350.0         655  ...    2008     250000             0
#
# ...

# %%
#Rótulos
labels = np.array(casa['SalePrice'])
#Removendo o rótulo da características
features= casa.drop('SalePrice', axis = 1)
#Salvando o nome da categoria para uso posterior
feature_list = list(casa.columns)
#Converte para um array numpy
casa = np.array(features)

# %%
#Importando libs e criando testes
from sklearn.model_selection import train_test_split
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.25, random_state = 42)

# %%
from sklearn.datasets import make_moons
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from sklearn import metrics

# %%
#GradientBoostingRegressor
grb = GradientBoostingRegressor(n_estimators=100)
grb.fit(train_features, train_labels)
gbr_pred = grb.predict(test_features)

# %%
#Calculando erro absoluto
errors_gbr = abs(gbr_pred - test_labels)

r_sq = grb.score(test_features, test_labels)
print('Coeficiente de Determinação (R²):', r_sq)

print('MAE:', metrics.mean_absolute_error(test_labels, gbr_pred))
print('MSE:', metrics.mean_squared_error(test_labels, gbr_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(test_labels, gbr_pred)))
# Out:
# Coeficiente de Determinação (R²): 0.8940825657136945
# MAE: 18545.33383180133
# MSE: 860093723.21469
# RMSE: 29327.354521243302

# %%
#Inicialização do objeto para Grid Search com validação cruzada.
from sklearn.model_selection import GridSearchCV


parameters = {'learning_rate': [0.03],
                  'subsample'    : [0.2],
                  'n_estimators' : [1000],
                  'max_depth'    : [8]
                 }

grid_search = GridSearchCV(grb, parameters, scoring='r2', cv=2, n_jobs=-1)

# %%
grid_search.fit(train_features, train_labels)
# Out:
# GridSearchCV(cv=2, estimator=GradientBoostingRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [0.03], 'max_depth': [8],
#                          'n_estimators': [1000], 'subsample': [0.2]},
#              scoring='r2')

# %%
    print(" Resultados do Grid Search " )
    print("\n O melhor estimador entre TODOS os parâmetros pesquisados:\n",grid_search.best_estimator_)
    print("\n A melhor pontuação entre TODOS os parâmetros pesquisados:\n",grid_search.best_score_)
    print("\n Os melhores parâmetros entre TODOS os parâmetros pesquisados:\n",grid_search.best_params_)
# Out:
#  Resultados do Grid Search
#
#  O melhor estimador entre TODOS os parâmetros pesquisados:
#  GradientBoostingRegressor(learning_rate=0.03, max_depth=8, n_estimators=1000,
#                           subsample=0.2)
#
#  A melhor pontuação entre TODOS os parâmetros pesquisados:
#  0.8387013353464097
#
#  Os melhores parâmetros entre TODOS os parâmetros pesquisados:
#  {'learning_rate': 0.03, 'max_depth': 8, 'n_estimators': 1000, 'subsample': 0.2}

# %%
best_model = grid_search.best_estimator_

# %%
#Parâmetros ajustados do melhor modelo selecionado
best_model.get_params()
# Out:
# {'alpha': 0.9,
#  'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.03,
#  'loss': 'squared_error',
#  'max_depth': 8,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 1000,
#  'n_iter_no_change': None,
#  'random_state': None,
#  'subsample': 0.2,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
#Inicialização do modelo de regressão por gradiente impulsionado com hiperparâmetros ajustados.
grb_tunned = GradientBoostingRegressor(alpha = 0.9,  ccp_alpha = 0.0,
 criterion = 'friedman_mse',
 init = None,
 learning_rate = 0.03,
 loss = 'squared_error',
 max_depth = 8,
 max_features = None,
 max_leaf_nodes = None,
 min_impurity_decrease = 0.0,
 min_samples_leaf = 1,
 min_samples_split = 2,
 min_weight_fraction_leaf = 0.0,
 n_estimators = 1000,
 n_iter_no_change = None,
 random_state = None,
 subsample = 0.2,
 tol = 0.0001,
 validation_fraction = 0.1,
 verbose = 0,
 warm_start = False)
grb_tunned.fit(train_features, train_labels)
gbr_tunned_pred = grb_tunned.predict(test_features)

# %%
#Calculando os erros absolutos
errors_gbr = abs(gbr_tunned_pred - test_labels)

r_sq = grb_tunned.score(test_features, test_labels)
print('Coeficiente de Determinação (R²):', r_sq)

print('MAE:', metrics.mean_absolute_error(test_labels, gbr_tunned_pred))
# Out:
# Coeficiente de Determinação (R²): 0.90402399492251
# MAE: 17387.0772163943
